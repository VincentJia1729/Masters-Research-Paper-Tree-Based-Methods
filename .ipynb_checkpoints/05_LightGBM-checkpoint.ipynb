# %% [markdown]
# # Part 5: Light GBM

# %% [markdown]
# ### Objective
#
# **Fit Model:** We will forecast the price of municipal green bonds on the "covid", "post_covid", and "full" dataset using *Light GBM*. To select the hyperparameters for our model, we will do time series cross validation on the training set. When doing this time series cross validation, we will when possible test the default hyperparameters against new hyperparameters. Sometimes, documentation on the tree model is not complete, and the exact default hyperparameter is not confidently known. Notice that we use a fixed seed when testing our hyperparameters and fitting our model.
#
# **Evaluate Forecast:** Once we have trained our model on the 80% of training data, we will test it against the 20% of testing data. We will plot the results of our forecasts for the "covid", "post covid", and "full" data sets. We will display the mean squared error (MSE), $r^2$, root mean squared error (RMSE), mean absolute error (MAE), and mean absolute percentage error (MAPE) of our forecats.
#
# **Explain Forecast:** Finally, we will use the "shap" package in python to plot various SHAP graphs, which will give us an explanation behind the drivers of our forecasted values over the testing set.

# %%
import lightgbm as lgb
import pandas as pd
import numpy as np
import shap
import my_functions
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...

# %% [markdown]
# ## Default Parameters

# %% [markdown]
# - n_estimators: 100
# - max_depth: -1 This means no limit on the depth of the tree.
# - learning_rate = 0.1
# - num_leaves: 31 (total number of leaves allowed in a tree)
#
# Note: we also have to adjust num leaves when adjusting max depth. We want to set num_leaves <= 2^max_depth. By default the maximum number of leaves is 31. We only adjust num leaves when max_depth is postive.
#
# Because of this contrivance, we will by default set our num_leaves parameter to 31. But this number can increase if the depth increases. But if the depth is unlimited, the num_leaves parameter will be 31. This is a slight error with the code, but the results should not change too much.

# %% [markdown]
# ## Import Data

# %%
# import all data
df_covid = pd.read_excel("./cleaned_excel_data/covid_data.xlsx")
df_post_covid = pd.read_excel("./cleaned_excel_data/post_covid_data.xlsx")
df_full = pd.read_excel("./cleaned_excel_data/full_data.xlsx")

# %%
# covid data
X_covid = df_covid.drop(columns=['date', 'mgb_log_diff'])
y_covid = df_covid['mgb_log_diff']
# train test split
split_idx = int(0.8 * len(df_covid))
X_train_covid, X_test_covid = X_covid[:split_idx], X_covid[split_idx:]
y_train_covid, y_test_covid = y_covid[:split_idx], y_covid[split_idx:]


# post covid data
X_post_covid = df_post_covid.drop(columns=['date', 'mgb_log_diff'])
y_post_covid = df_post_covid['mgb_log_diff']
# train test split
split_idx = int(0.8 * len(df_post_covid))
X_train_post_covid, X_test_post_covid = X_post_covid[:split_idx], X_post_covid[split_idx:]
y_train_post_covid, y_test_post_covid = y_post_covid[:split_idx], y_post_covid[split_idx:]

# full data
X_full = df_full.drop(columns=['date', 'mgb_log_diff'])
y_full = df_full['mgb_log_diff']
# train test split
split_idx = int(0.8 * len(df_full))
X_train_full, X_test_full = X_full[:split_idx], X_full[split_idx:]
y_train_full, y_test_full = y_full[:split_idx], y_full[split_idx:]

# %% [markdown]
# ## Find Optimal Parameters (Time Series Cross Validation)

# %%
param_grid = {
    'max_depth': [4, 6, 8, -1],
    'n_estimators' : [100, 150,200],
    'learning_rate':[0.05, 0.075, 0.1 ],
    'num_leaves': [31],
    'random_state': [1]
}

# %% [markdown]
# #### Covid Time Period

# %%
best_params_covid, best_mse_covid = my_functions.time_series_cv_tuning_lightgbm(X_train_covid, y_train_covid, param_grid, print_results = False)
# Out:
# Testing parameters: {'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.05, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 129.2142
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.075, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 143.9413
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 143.5393
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 150, 'learning_rate': 0.05, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 143.3282
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 150, 'learning_rate': 0.075, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 159.3602
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 150, 'learning_rate': 0.1, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 158.2795
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 200, 'learning_rate': 0.05, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 153.8500
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 200, 'learning_rate': 0.075, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 172.6091
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 200, 'learning_rate': 0.1, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 166.0559
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 100, 'learning_rate': 0.05, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 130.5631
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 100, 'learning_rate': 0.075, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 142.4325
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 157.1365
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 150, 'learning_rate': 0.05, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 146.4029
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 150, 'learning_rate': 0.075, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 152.9459
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 150, 'learning_rate': 0.1, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 172.2162
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 200, 'learning_rate': 0.05, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 157.8257
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 200, 'learning_rate': 0.075, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 165.4029
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 200, 'learning_rate': 0.1, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 180.2269
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 100, 'learning_rate': 0.05, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 128.3176
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 100, 'learning_rate': 0.075, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 140.0772
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 147.4773
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 150, 'learning_rate': 0.05, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 140.9591
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 150, 'learning_rate': 0.075, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 149.0159
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 150, 'learning_rate': 0.1, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 162.4356
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 200, 'learning_rate': 0.05, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 146.9314
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 200, 'learning_rate': 0.075, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 160.2629
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 200, 'learning_rate': 0.1, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 171.5492
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 100, 'learning_rate': 0.05, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 129.5241
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 100, 'learning_rate': 0.075, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 139.4800
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 147.2853
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 150, 'learning_rate': 0.05, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 137.6393
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 150, 'learning_rate': 0.075, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 149.2673
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 150, 'learning_rate': 0.1, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 165.7015
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 200, 'learning_rate': 0.05, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 142.5178
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 200, 'learning_rate': 0.075, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 158.5049
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 200, 'learning_rate': 0.1, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 169.5788
#
# Best Parameters: {'max_depth': 8, 'n_estimators': 100, 'learning_rate': 0.05, 'num_leaves': 256, 'random_state': 1}
# Best MSE: 128.3176

# %% [markdown]
# #### Post Covid Time Period

# %%
best_params_post_covid, best_mse_post_covid = (
    my_functions.time_series_cv_tuning_lightgbm(X_train_post_covid, y_train_post_covid, param_grid, print_results = False)
)
# Out:
# Testing parameters: {'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.05, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 28.8564
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.075, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 29.6376
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 30.3704
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 150, 'learning_rate': 0.05, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 29.4676
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 150, 'learning_rate': 0.075, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 30.6378
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 150, 'learning_rate': 0.1, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 31.5704
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 200, 'learning_rate': 0.05, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 30.1338
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 200, 'learning_rate': 0.075, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 31.4540
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 200, 'learning_rate': 0.1, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 32.4050
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 100, 'learning_rate': 0.05, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 28.8548
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 100, 'learning_rate': 0.075, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 29.8723
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 30.2812
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 150, 'learning_rate': 0.05, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 29.3393
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 150, 'learning_rate': 0.075, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 30.8071
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 150, 'learning_rate': 0.1, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 31.2104
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 200, 'learning_rate': 0.05, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 30.0153
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 200, 'learning_rate': 0.075, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 31.6006
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 200, 'learning_rate': 0.1, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 32.1897
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 100, 'learning_rate': 0.05, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 28.6474
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 100, 'learning_rate': 0.075, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 29.5421
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 30.0831
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 150, 'learning_rate': 0.05, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 29.2165
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 150, 'learning_rate': 0.075, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 30.6458
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 150, 'learning_rate': 0.1, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 31.1093
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 200, 'learning_rate': 0.05, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 30.0371
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 200, 'learning_rate': 0.075, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 31.7363
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 200, 'learning_rate': 0.1, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 31.9462
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 100, 'learning_rate': 0.05, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 28.6179
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 100, 'learning_rate': 0.075, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 29.4202
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 30.1147
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 150, 'learning_rate': 0.05, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 29.1368
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 150, 'learning_rate': 0.075, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 30.4487
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 150, 'learning_rate': 0.1, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 31.0614
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 200, 'learning_rate': 0.05, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 30.0101
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 200, 'learning_rate': 0.075, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 31.2854
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 200, 'learning_rate': 0.1, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 31.7235
#
# Best Parameters: {'max_depth': -1, 'n_estimators': 100, 'learning_rate': 0.05, 'num_leaves': 31, 'random_state': 1}
# Best MSE: 28.6179

# %% [markdown]
# #### Full Time Period

# %%
best_params_full, best_mse_full = my_functions.time_series_cv_tuning_lightgbm(X_train_full, y_train_full, param_grid, print_results = False)
# Out:
# Testing parameters: {'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.05, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 113.5988
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.075, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 117.7641
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 125.0112
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 150, 'learning_rate': 0.05, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 118.8007
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 150, 'learning_rate': 0.075, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 122.5019
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 150, 'learning_rate': 0.1, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 130.2743
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 200, 'learning_rate': 0.05, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 121.7773
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 200, 'learning_rate': 0.075, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 126.1940
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 200, 'learning_rate': 0.1, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 132.5990
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 100, 'learning_rate': 0.05, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 110.9254
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 100, 'learning_rate': 0.075, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 115.7644
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 119.9016
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 150, 'learning_rate': 0.05, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 115.1609
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 150, 'learning_rate': 0.075, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 122.5052
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 150, 'learning_rate': 0.1, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 128.5317
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 200, 'learning_rate': 0.05, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 118.2980
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 200, 'learning_rate': 0.075, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 127.2771
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 200, 'learning_rate': 0.1, 'num_leaves': 64, 'random_state': 1}
# Avg MSE: 137.6589
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 100, 'learning_rate': 0.05, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 112.2497
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 100, 'learning_rate': 0.075, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 115.3429
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 119.2241
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 150, 'learning_rate': 0.05, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 115.3138
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 150, 'learning_rate': 0.075, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 120.9948
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 150, 'learning_rate': 0.1, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 128.0503
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 200, 'learning_rate': 0.05, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 118.4061
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 200, 'learning_rate': 0.075, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 127.3116
#
# Testing parameters: {'max_depth': 8, 'n_estimators': 200, 'learning_rate': 0.1, 'num_leaves': 256, 'random_state': 1}
# Avg MSE: 135.4527
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 100, 'learning_rate': 0.05, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 111.1797
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 100, 'learning_rate': 0.075, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 118.7821
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 100, 'learning_rate': 0.1, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 120.3157
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 150, 'learning_rate': 0.05, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 115.4759
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 150, 'learning_rate': 0.075, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 124.3194
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 150, 'learning_rate': 0.1, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 129.1128
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 200, 'learning_rate': 0.05, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 118.2599
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 200, 'learning_rate': 0.075, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 129.5292
#
# Testing parameters: {'max_depth': -1, 'n_estimators': 200, 'learning_rate': 0.1, 'num_leaves': 31, 'random_state': 1}
# Avg MSE: 136.4815
#
# Best Parameters: {'max_depth': 6, 'n_estimators': 100, 'learning_rate': 0.05, 'num_leaves': 64, 'random_state': 1}
# Best MSE: 110.9254

# %% [markdown]
# ## See Quality of Prediction

# %% [markdown]
# We will use the optimal parameters to train the model

# %% [markdown]
# #### Covid Time Period

# %%
model_lightgbm_covid =  lgb.LGBMRegressor(verbosity=-1, n_jobs=1,  **best_params_covid)
model_lightgbm_covid.fit(X_train_covid, y_train_covid)
# Out:
# LGBMRegressor(learning_rate=0.05, max_depth=8, n_jobs=1, num_leaves=256,
#               random_state=1, verbosity=-1)

# %%
metrics = my_functions.evaluate_model_performance(model_lightgbm_covid, X_test_covid, y_test_covid, 
                                   model_name="lightgbm", target_name="y_covid")
# Out:
# MSE of lightgbm: 70.7216
# R squared of lightgbm: -0.0961
# RMSE of lightgbm: 8.4096
# MAE of lightgbm: 6.0639
# MAPE of lightgbm: 1.49%

# %% [markdown]
# #### Post Covid Time Period

# %%
model_lightgbm_post_covid =  lgb.LGBMRegressor(verbosity=-1, n_jobs=1,**best_params_post_covid)
model_lightgbm_post_covid.fit(X_train_post_covid, y_train_post_covid)
# Out:
# LGBMRegressor(learning_rate=0.05, n_jobs=1, random_state=1, verbosity=-1)

# %%
metrics = my_functions.evaluate_model_performance(model_lightgbm_post_covid, X_test_post_covid, y_test_post_covid, 
                                   model_name="lightgbm", target_name="y_post_covid")
# Out:
# MSE of lightgbm: 34.6740
# R squared of lightgbm: 0.2667
# RMSE of lightgbm: 5.8885
# MAE of lightgbm: 4.0992
# MAPE of lightgbm: 1.27%

# %% [markdown]
# #### Full Time Period

# %%
model_lightgbm_full = lgb.LGBMRegressor(verbosity=-1, n_jobs=1, **best_params_full)
model_lightgbm_full.fit(X_train_full, y_train_full)
# Out:
# LGBMRegressor(learning_rate=0.05, max_depth=6, n_jobs=1, num_leaves=64,
#               random_state=1, verbosity=-1)

# %%
metrics = my_functions.evaluate_model_performance(model_lightgbm_full, X_test_full, y_test_full, 
                                   model_name="lightgbm", target_name="y_full")
# Out:
# MSE of lightgbm: 23.3112
# R squared of lightgbm: 0.4015
# RMSE of lightgbm: 4.8282
# MAE of lightgbm: 3.3778
# MAPE of lightgbm: 1.05%

# %% [markdown]
# ## SHAP Plots

# %% [markdown]
# We will fit SHAP plots onto the test set.

# %% [markdown]
# #### Covid Time Period

# %%
shap_covid = my_functions.shap_analysis_complete(model_lightgbm_covid, X_train_covid,  X_test_covid, 
                                model_name="lightgbm", n_cols=3)
# Out:
# 1. Beeswarm plot
# 2. Feature importance bar plot
# 3. Dependence plots grid
# 4. Heatmap ordered by predictions

# %% [markdown]
# #### Post Covid Time Period

# %%
shap_post_covid = my_functions.shap_analysis_complete(model_lightgbm_post_covid, X_train_post_covid, X_test_post_covid, 
                                model_name="lightgbm", n_cols=3)
# Out:
# 1. Beeswarm plot
# 2. Feature importance bar plot
# 3. Dependence plots grid
# 4. Heatmap ordered by predictions

# %% [markdown]
# #### Full Time Period

# %%
shap_full = my_functions.shap_analysis_complete(model_lightgbm_full, X_train_full, X_test_full, 
                                model_name="lightgbm", n_cols=3)
# Out:
# 1. Beeswarm plot
# 2. Feature importance bar plot
# 3. Dependence plots grid
# 4. Heatmap ordered by predictions
