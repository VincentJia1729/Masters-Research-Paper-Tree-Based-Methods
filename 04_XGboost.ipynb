# %% [markdown]
# # Part 4: XGBoost

# %% [markdown]
# ### Objective
#
# **Fit Model:** We will forecast the price of municipal green bonds on the "covid", "post_covid", and "full" dataset using *XGBoost*. To select the hyperparameters for our model, we will do time series cross validation on the training set. When doing this time series cross validation, we will when possible test the default hyperparameters against new hyperparameters. Sometimes, documentation on the tree model is not complete, and the exact default hyperparameter is not confidently known.
#
# **Evaluate Forecast:** Once we have trained our model on the 80% of training data, we will test it against the 20% of testing data. We will plot the results of our forecasts for the "covid", "post covid", and "full" data sets. We will display the mean squared error (MSE), $r^2$, root mean squared error (RMSE), mean absolute error (MAE), and mean absolute percentage error (MAPE) of our forecats.
#
# **Explain Forecast:** Finally, we will use the "shap" package in python to plot various SHAP graphs, which will give us an explanation behind the drivers of our forecasted values over the testing set.

# %%
import xgboost as xgb
import pandas as pd
import numpy as np
import shap

import my_functions

shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...

# %% [markdown]
# ## Default Parameters

# %% [markdown]
# - n_estimators: 100
# - max_depth: 6
# - learning_rate: 0.3

# %% [markdown]
# ## Import Data

# %%
# import all data
df_covid = pd.read_excel("./cleaned_excel_data/covid_data.xlsx")
df_post_covid = pd.read_excel("./cleaned_excel_data/post_covid_data.xlsx")
df_full = pd.read_excel("./cleaned_excel_data/full_data.xlsx")

# %%
# covid data
X_covid = df_covid.drop(columns=['date', 'mgb_log_diff'])
y_covid = df_covid['mgb_log_diff']
# train test split
split_idx = int(0.8 * len(df_covid))
X_train_covid, X_test_covid = X_covid[:split_idx], X_covid[split_idx:]
y_train_covid, y_test_covid = y_covid[:split_idx], y_covid[split_idx:]


# post covid data
X_post_covid = df_post_covid.drop(columns=['date', 'mgb_log_diff'])
y_post_covid = df_post_covid['mgb_log_diff']
# train test split
split_idx = int(0.8 * len(df_post_covid))
X_train_post_covid, X_test_post_covid = X_post_covid[:split_idx], X_post_covid[split_idx:]
y_train_post_covid, y_test_post_covid = y_post_covid[:split_idx], y_post_covid[split_idx:]

# full data
X_full = df_full.drop(columns=['date', 'mgb_log_diff'])
y_full = df_full['mgb_log_diff']
# train test split
split_idx = int(0.8 * len(df_full))
X_train_full, X_test_full = X_full[:split_idx], X_full[split_idx:]
y_train_full, y_test_full = y_full[:split_idx], y_full[split_idx:]

# %% [markdown]
# ## Find Optimal Parameters (Time Series Cross Validation)

# %%
param_grid = {
    'max_depth': [4,5,6],
    'n_estimators' : [75, 100, 125],
    'learning_rate' : [0.01, 0.02, 0.3]
}

# %% [markdown]
# #### Covid Time Period

# %%
best_params_covid, best_mse_covid = my_functions.time_series_cv_tuning_xgboost(X_train_covid, y_train_covid, param_grid, print_results = False)
# Out:
# Testing parameters: {'max_depth': 4, 'n_estimators': 75, 'learning_rate': 0.01}
# Avg MSE: 218.5594
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 75, 'learning_rate': 0.02}
# Avg MSE: 219.7072
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 75, 'learning_rate': 0.3}
# Avg MSE: 419.2132
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.01}
# Avg MSE: 217.5464
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.02}
# Avg MSE: 220.5000
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.3}
# Avg MSE: 422.1559
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 125, 'learning_rate': 0.01}
# Avg MSE: 216.9259
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 125, 'learning_rate': 0.02}
# Avg MSE: 256.5915
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 125, 'learning_rate': 0.3}
# Avg MSE: 422.2227
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 75, 'learning_rate': 0.01}
# Avg MSE: 316.1831
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 75, 'learning_rate': 0.02}
# Avg MSE: 508.8201
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 75, 'learning_rate': 0.3}
# Avg MSE: 803.8161
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 100, 'learning_rate': 0.01}
# Avg MSE: 426.8267
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 100, 'learning_rate': 0.02}
# Avg MSE: 547.4103
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 100, 'learning_rate': 0.3}
# Avg MSE: 803.5949
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 125, 'learning_rate': 0.01}
# Avg MSE: 499.3258
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 125, 'learning_rate': 0.02}
# Avg MSE: 620.1709
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 125, 'learning_rate': 0.3}
# Avg MSE: 803.8178
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 75, 'learning_rate': 0.01}
# Avg MSE: 319.1404
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 75, 'learning_rate': 0.02}
# Avg MSE: 653.6716
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 75, 'learning_rate': 0.3}
# Avg MSE: 1115.5354
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 100, 'learning_rate': 0.01}
# Avg MSE: 430.1923
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 100, 'learning_rate': 0.02}
# Avg MSE: 843.3113
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 100, 'learning_rate': 0.3}
# Avg MSE: 1115.6742
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 125, 'learning_rate': 0.01}
# Avg MSE: 542.9007
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 125, 'learning_rate': 0.02}
# Avg MSE: 982.5559
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 125, 'learning_rate': 0.3}
# Avg MSE: 1115.6580
#
# Best Parameters: {'max_depth': 4, 'n_estimators': 125, 'learning_rate': 0.01}
# Best MSE: 216.9259

# %% [markdown]
# #### Post Covid Time Period

# %%
best_params_post_covid, best_mse_post_covid = (
    my_functions.time_series_cv_tuning_xgboost(X_train_post_covid, y_train_post_covid, param_grid, print_results = False)
)
# Out:
# Testing parameters: {'max_depth': 4, 'n_estimators': 75, 'learning_rate': 0.01}
# Avg MSE: 30.4771
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 75, 'learning_rate': 0.02}
# Avg MSE: 30.9439
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 75, 'learning_rate': 0.3}
# Avg MSE: 40.6355
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.01}
# Avg MSE: 29.9457
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.02}
# Avg MSE: 33.1599
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.3}
# Avg MSE: 40.6412
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 125, 'learning_rate': 0.01}
# Avg MSE: 30.1053
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 125, 'learning_rate': 0.02}
# Avg MSE: 35.0704
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 125, 'learning_rate': 0.3}
# Avg MSE: 40.6564
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 75, 'learning_rate': 0.01}
# Avg MSE: 30.9730
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 75, 'learning_rate': 0.02}
# Avg MSE: 31.5883
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 75, 'learning_rate': 0.3}
# Avg MSE: 44.8589
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 100, 'learning_rate': 0.01}
# Avg MSE: 30.2129
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 100, 'learning_rate': 0.02}
# Avg MSE: 34.5828
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 100, 'learning_rate': 0.3}
# Avg MSE: 44.8594
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 125, 'learning_rate': 0.01}
# Avg MSE: 30.4889
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 125, 'learning_rate': 0.02}
# Avg MSE: 37.4124
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 125, 'learning_rate': 0.3}
# Avg MSE: 44.8595
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 75, 'learning_rate': 0.01}
# Avg MSE: 31.4659
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 75, 'learning_rate': 0.02}
# Avg MSE: 32.2302
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 75, 'learning_rate': 0.3}
# Avg MSE: 43.5750
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 100, 'learning_rate': 0.01}
# Avg MSE: 31.5150
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 100, 'learning_rate': 0.02}
# Avg MSE: 34.8711
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 100, 'learning_rate': 0.3}
# Avg MSE: 43.5772
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 125, 'learning_rate': 0.01}
# Avg MSE: 31.7258
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 125, 'learning_rate': 0.02}
# Avg MSE: 37.3202
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 125, 'learning_rate': 0.3}
# Avg MSE: 43.5773
#
# Best Parameters: {'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.01}
# Best MSE: 29.9457

# %% [markdown]
# #### Full Time Period

# %%
best_params_full, best_mse_full = my_functions.time_series_cv_tuning_xgboost(X_train_full, y_train_full, param_grid, print_results = False)
# Out:
# Testing parameters: {'max_depth': 4, 'n_estimators': 75, 'learning_rate': 0.01}
# Avg MSE: 267.4442
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 75, 'learning_rate': 0.02}
# Avg MSE: 355.5472
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 75, 'learning_rate': 0.3}
# Avg MSE: 648.5057
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.01}
# Avg MSE: 342.6460
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.02}
# Avg MSE: 386.7024
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.3}
# Avg MSE: 647.1746
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 125, 'learning_rate': 0.01}
# Avg MSE: 349.4663
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 125, 'learning_rate': 0.02}
# Avg MSE: 425.1783
#
# Testing parameters: {'max_depth': 4, 'n_estimators': 125, 'learning_rate': 0.3}
# Avg MSE: 647.9514
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 75, 'learning_rate': 0.01}
# Avg MSE: 266.6445
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 75, 'learning_rate': 0.02}
# Avg MSE: 539.6280
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 75, 'learning_rate': 0.3}
# Avg MSE: 576.2672
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 100, 'learning_rate': 0.01}
# Avg MSE: 357.4607
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 100, 'learning_rate': 0.02}
# Avg MSE: 575.6077
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 100, 'learning_rate': 0.3}
# Avg MSE: 577.2547
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 125, 'learning_rate': 0.01}
# Avg MSE: 449.5064
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 125, 'learning_rate': 0.02}
# Avg MSE: 592.0971
#
# Testing parameters: {'max_depth': 5, 'n_estimators': 125, 'learning_rate': 0.3}
# Avg MSE: 577.4539
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 75, 'learning_rate': 0.01}
# Avg MSE: 266.7425
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 75, 'learning_rate': 0.02}
# Avg MSE: 540.0538
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 75, 'learning_rate': 0.3}
# Avg MSE: 752.9118
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 100, 'learning_rate': 0.01}
# Avg MSE: 357.6425
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 100, 'learning_rate': 0.02}
# Avg MSE: 670.1147
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 100, 'learning_rate': 0.3}
# Avg MSE: 753.0899
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 125, 'learning_rate': 0.01}
# Avg MSE: 449.7150
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 125, 'learning_rate': 0.02}
# Avg MSE: 669.9267
#
# Testing parameters: {'max_depth': 6, 'n_estimators': 125, 'learning_rate': 0.3}
# Avg MSE: 753.1403
#
# Best Parameters: {'max_depth': 5, 'n_estimators': 75, 'learning_rate': 0.01}
# Best MSE: 266.6445

# %% [markdown]
# ## See Quality of Prediction

# %% [markdown]
# We will use the optimal parameters to train the model

# %% [markdown]
# #### Covid Time Period

# %%
model_xgboost_covid =  xgb.XGBRegressor(objective = 'reg:squarederror', verbosity = 0, **best_params_covid)
model_xgboost_covid.fit(X_train_covid, y_train_covid)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=125,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
metrics = my_functions.evaluate_model_performance(model_xgboost_covid, X_test_covid, y_test_covid, 
                                   model_name="XGBoost", target_name="y_covid")
# Out:
# MSE of XGBoost: 60.0546
# R² of XGBoost: 0.0693
# RMSE of XGBoost: 7.7495
# MAE of XGBoost: 5.0784
# MAPE of XGBoost: 1.64%

# %% [markdown]
# #### Post Covid Time Period

# %%
model_xgboost_post_covid = xgb.XGBRegressor(objective = 'reg:squarederror', verbosity = 0, **best_params_post_covid)
model_xgboost_post_covid.fit(X_train_post_covid, y_train_post_covid)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
metrics = my_functions.evaluate_model_performance(model_xgboost_post_covid, X_test_post_covid, y_test_post_covid, 
                                   model_name="XGBoost", target_name="y_post_covid")
# Out:
# MSE of XGBoost: 36.2397
# R² of XGBoost: 0.2336
# RMSE of XGBoost: 6.0199
# MAE of XGBoost: 3.8957
# MAPE of XGBoost: 1.35%

# %% [markdown]
# #### Full Time Period

# %%
model_xgboost_full = xgb.XGBRegressor(objective = 'reg:squarederror', verbosity = 0, **best_params_full)
model_xgboost_full.fit(X_train_full, y_train_full)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=75,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
metrics = my_functions.evaluate_model_performance(model_xgboost_full, X_test_full, y_test_full, 
                                   model_name="XGBoost", target_name="y_full")
# Out:
# MSE of XGBoost: 30.9919
# R² of XGBoost: 0.2043
# RMSE of XGBoost: 5.5670
# MAE of XGBoost: 3.5291
# MAPE of XGBoost: 1.24%

# %% [markdown]
# ## SHAP Plots

# %% [markdown]
# We will fit SHAP plots onto the test set.

# %% [markdown]
# #### Covid Time Period

# %%
shap_covid = my_functions.shap_analysis_complete(model_xgboost_covid, X_train_covid, X_test_covid, 
                                model_name="XGBoost", n_cols=3)
# Out:
# 1. Beeswarm plot
# 2. Feature importance bar plot
# 3. Dependence plots grid
# 4. Heatmap ordered by predictions

# %% [markdown]
# #### Post Covid Time Period

# %%
shap_post_covid = my_functions.shap_analysis_complete(model_xgboost_post_covid, X_train_post_covid, X_test_post_covid, 
                                model_name="XGBoost", n_cols=3)
# Out:
# 1. Beeswarm plot
# 2. Feature importance bar plot
# 3. Dependence plots grid
# 4. Heatmap ordered by predictions

# %% [markdown]
# #### Full Time Period

# %%
shap_full = my_functions.shap_analysis_complete(model_xgboost_full, X_train_full, X_test_full, 
                                model_name="XGBoost", n_cols=3)
# Out:
# 1. Beeswarm plot
# 2. Feature importance bar plot
# 3. Dependence plots grid
# 4. Heatmap ordered by predictions
